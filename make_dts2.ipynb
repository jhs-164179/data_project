# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from tqdm import tqdm

# %%
car=pd.read_csv('eleccar.csv')
human=pd.read_csv('human.csv')

# %%
display(car.head(),human.head())
# Out:
#                읍면동  2020전기차  2021전기차  2022전기차  2020전기차비율  2021전기차비율  \
# 0      제주특별자치도 제주시  12182.0  14432.0  18463.0       2.68       3.02
# 1     제주특별자치도 서귀포시   2968.0   3626.0   4516.0       5.28       6.31
# 2  제주특별자치도 제주시 애월읍   1192.0   1430.0   1831.0       5.13       5.97
# 3  제주특별자치도 제주시 조천읍    835.0    986.0   1273.0       5.61       6.45
# 4  제주특별자치도 제주시 한림읍    713.0    839.0   1064.0       5.61       6.42
#
#    2022전기차비율  2021전기차증감율  2122전기차증감율
# 0       3.63       18.47       27.93
# 1       7.70       22.17       24.54
# 2       7.48       19.97       28.04
# 3       8.17       18.08       29.11
# 4       8.10       17.67       26.82
#               행정구역    2020인구    2021인구    2022인구  2020경제활동인구  2021경제활동인구  \
# 0      제주특별자치도 제주시  380654.0  380948.0  380973.0    220665.0    222656.0
# 1  제주특별자치도 제주시 애월읍   36842.0   37579.0   37649.0     21593.0     22057.0
# 2  제주특별자치도 제주시 조천읍   25328.0   25493.0   25727.0     15119.0     15218.0
# ...
